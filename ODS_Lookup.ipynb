# %% [markdown]
# <a href="https://colab.research.google.com/github/dvavasour/Colabatory/blob/master/ODS_Lookup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytricia
# Out:
# ...
#   Created wheel for pytricia: filename=pytricia-1.0.1-cp36-cp36m-linux_x86_64.whl size=47320 sha256=4cc037afbbdd95b5d2451e00e91bb9068bffe116dde223d8f640c661943e4e4d
#   Stored in directory: /root/.cache/pip/wheels/db/f7/b7/8c30fd3ca29101b947b89b6485960a8f8e5057d2eea06e9018
# Successfully built pytricia
# ...

# %%
import pytricia

# %%
with open("BGP_Summary.csv") as f:
  for line in f:
    print(line)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# "172.31.210.0/24","SD035"
#
# "172.31.245.0/24","D83060"
#
# "176.62.208.0/24","8HG86"
#
# "185.143.214.0/24","RYA05"
#
# "193.132.224.0/24","RQ617"
#
# "193.132.225.0/24","RQ617"
#
# "193.132.227.0/24","REM21"
#
# "193.240.116.0/24","RRK02"
#
# "193.240.182.0/24","RXT54"
#
# "193.240.192.0/24","RRK98"
#
# "194.0.76.0/24","8K965"
#
# "194.61.247.0/24","8HK22"
#
# "194.62.102.0/24","8HK22"
#
# "194.101.1.0/24","T1450"
#
# "194.101.2.0/24","RTK"
#
# "194.101.3.0/24","RNS01"
#
# "194.101.10.0/24","8HC49"
#
# "194.101.11.0/24","10X"
#
# "194.101.12.0/24","RTG02"
#
# "194.101.17.0/24","RVV01"
#
# "194.101.20.0/24","RVVKC"
#
# "194.101.21.0/24","0AR"
#
# "194.101.32.0/24","RNN"
#
# "194.101.34.0/24","RVVKC"
#
# "194.101.35.0/24","RR8"
#
# "194.101.40.0/24","R1F01"
#
# "194.101.41.0/24","R1F01"
#
# "194.101.42.0/24","R1F01"
#
# "194.101.43.0/24","R1F01"
#
# "194.101.52.0/24","RA7"
#
# "194.101.53.0/24","RA701"
#
# ...
